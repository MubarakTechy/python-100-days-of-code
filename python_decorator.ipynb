# %% [markdown]
# ### Python Decorators

# %% [markdown]
# Decorators let you add extra behavior to a function, without changing the function's code.
#
# A decorator is a function that takes another function as input and returns a new function.

# %% [markdown]
# Define the decorator first, then apply it with @decorator_name above the function.

# %%
def change(punk):
  def myinner():
    return punk().upper()
  return myinner

@change
def mkpunk():
  return "Hello Sally"

print(mkpunk())
# Out:
# HELLO SALLY

# %% [markdown]
# By placing @changecase directly above the function definition, the function myfunction is being "decorated" with the changecase function.
#
# The function changecase is the decorator.
#
# The function myfunction is the function that gets decorated.

# %% [markdown]
# #### Multiple Decorator Calls
#
# A decorator can be called multiple times. Just place the decorator above the function you want to decorate.

# %% [markdown]
# Using the @changecase decorator on two functions:

# %%
def farmer(product):
  def myinner():
    return product().upper()
  return myinner

@farmer
def maize():
  return "Farming Maize"

@farmer
def beans():
  return "I am farming beans"

print(maize())
print(beans())
# Out:
# FARMING MAIZE
# I AM FARMING BEANS

# %% [markdown]
# #### Arguments in the Decorated Function
# Functions that requires arguments can also be decorated, just make sure you pass the arguments to the wrapper function:

# %%
def changecase(func):
  def myinner(x,y):
    return func(x,y).upper()
  return myinner

@changecase
def myfunction(nam, age):
  return f"Hello  {nam} {age}"

print(myfunction("John",20))
# Out:
# HELLO  JOHN 20

# %% [markdown]
# #### *args and **kwargs
#
# Sometimes the decorator function has no control over the arguments passed from decorated function, to solve this problem, add (*args, **kwargs) to the wrapper function, this way the wrapper function can accept any number, and any type of arguments, and pass them to the decorated function.

# %%
def changecase(func):
  def myinner(*args, **kwargs):
    return func(*args, **kwargs).upper()
  return myinner

@changecase
def myfunction(nam, gender):
  return "Hello " + nam +" "+ gender

print(myfunction("John", "Male"))
# Out:
# HELLO JOHN MALE

# %% [markdown]
# #### Decorator With Arguments
# Decorators can accept their own arguments by adding another wrapper level.

# %%
def changecase(n):
  def changecase(func):
    def myinner():
      if n == 1:
        a = func().lower()
      else:
        a = func().upper()
      return a
    return myinner
  return changecase

@changecase(10)
def myfunction():
  return "Hello Linus"

print(myfunction())
# Out:
# HELLO LINUS

# %% [markdown]
# #### Multiple Decorators
# You can use multiple decorators on one function.
#
# This is done by placing the decorator calls on top of each other.
#
# The decorators are called in the order they are specified.

# %%
def changecase(func):
  def myinner():
    return func().upper()
  return myinner

def addgreeting(func):
  def myinner():
    return "Hello " + func() + " Have a good day!"
  return myinner

@changecase
@addgreeting
def myfunction():
  return "Tobias"

print(myfunction())
# Out:
# HELLO TOBIAS HAVE A GOOD DAY!

# %% [markdown]
# #### Preserving Function Metadata
# Functions in Python has metadata that can be accessed using the __name__ and __doc__ attributes.

# %% [markdown]
# Normally, a function's name can be returned with the `__name__` attribute:

# %%
def myfunction():
    """This function returns a string."""
    return "Have a great day!"

print(myfunction.__name__)
print(myfunction.__doc__)
# Out:
# myfunction
# This function returns a string.

# %% [markdown]
# But, when a function is decorated, the metadata of the original function is lost.
#
# Try returning the name from a decorated function and you will not get the same result:

# %%
def changecase(func):
  def myinner():
    return func().upper()
  return myinner

@changecase
def myfunction():
  return "Have a great day!"

print(myfunction.__name__)
# Out:
# myinner

# %% [markdown]
# To fix this, Python has a built-in function called functools.wraps that can be used to preserve the original function's name and docstring.

# %% [markdown]
# Import functools.wraps to preserve the original function name and docstring.

# %%
import functools

def changecase(func):
  @functools.wraps(func)
  def myinner():
    """This the inner function that changes case."""
    return func().upper()
  return myinner

@changecase
def myfunction():
  """This function returns a string."""
  return "Have a great day!"

print(myfunction.__name__)
print(myfunction.__doc__)
# Out:
# myfunction
# This function returns a string.

# %% [markdown]
# ### Excersice

# %% [markdown]
# --------------------------------------------------
# 1.  Basic decorator – build & apply
# --------------------------------------------------
# Exercise
# Write a decorator `reverse` that returns the **reversed string** of the decorated function’s result.
# Apply it to `greet()` so the code below prints **“yllaS olleH”**.
#
# ```python
# @reverse
# def greet():
#     return "Hello Sally"
#
# print(greet())   # ➜ yllaS olleH
# ```
#
#
# --------------------------------------------------
# 2.  Multiple decorator calls
# --------------------------------------------------
# Exercise
# Use the same `reverse` on **two different functions** (`greet` and `farewell`) and print both results.
#
# ```python
# @reverse
# def greet():
#     return "Hi"
#
# @reverse
# def farewell():
#     return "Goodbye"
#
# print(greet())      # ➜ iH
# print(farewell())   # ➜ eybdoog
# ```
#
# --------------------------------------------------
# 3.  Arguments in the decorated function
# --------------------------------------------------
# Exercise
# Create decorator `add_smiley` that takes the decorated function’s return value and appends **“ 😊”**.
# The decorated function **requires one argument** (`name`).
# Test:
#
# ```python
# @add_smiley
# def make_text(name):
#     return f"Hi {name}"
#
# print(make_text("Ada"))   # ➜ Hi Ada 😊
# ```
#
# --------------------------------------------------
# 4.  *args and **kwargs – generic wrapper
# --------------------------------------------------
# Exercise
# Rewrite `add_smiley` so it works **no matter how many positional/keyword arguments** the decorated function uses.
# Demonstrate with:
#
# ```python
# @add_smiley
# def build_greeting(greeting, name, punctuation="!"):
#     return f"{greeting} {name}{punctuation}"
#
# print(build_greeting("Hello", "Grace", punctuation="..."))
# # ➜ Hello Grace... 😊
# ```
#
# --------------------------------------------------
# 5.  Decorator with arguments (factory)
# --------------------------------------------------
# Exercise
# Build a decorator factory `surround_with(symbol)` that wraps the return value **on both sides** with the given symbol.
# Usage:
#
# ```python
# @surround_with(">>>")
# def shout():
#     return "attention"
#
# print(shout())   # ➜ >>>attention>>>
# ```
#
# --------------------------------------------------
# 6.  Multiple decorators (stacking)
# --------------------------------------------------
# Exercise
# Stack two decorators:
# 1. `uppercase` – makes string upper-case.
# 2. `quote` – wraps string in double quotes.
#
# Apply them so the final result is **quoted then upper-cased** (order matters).
# Expected: `"HELLO WORLD"`
#
# ```python
# @uppercase
# @quote
# def msg():
#     return "hello world"
#
# print(msg())   # ➜ "HELLO WORLD"
# ```
#
#
# --------------------------------------------------
# 7.  Preserving function metadata
# --------------------------------------------------
# Exercise
# Add `@functools.wraps` to the `uppercase` decorator so that
# `msg.__name__` and `msg.__doc__` return the original function’s metadata instead of `"wrapper"`.
#
# ```python
# @uppercase
# def msg():
#     """Return a friendly string."""
#     return "hello"
#
# print(msg.__name__)  # ➜ msg
# print(msg.__doc__)   # ➜ Return a friendly string.
# ```
